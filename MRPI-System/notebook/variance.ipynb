# %%
import sys
sys.path.append("../")

from src.CF import build_cf_model

data = build_cf_model()
print(f"Variance expliquée: {data['svd_variance']:.4f}")
# Out:
# INFO:src.CF:Raw-KNN construit: 39 étudiants, 97 ressources (variance SVD=0.2791 < seuil 0.5)
# INFO:src.CF:✓ Modèle CF sauvegardé: c:\machine learning\MRPI\MRPI-System\models\cf_model.pkl
# Variance expliquée: 0.2791
